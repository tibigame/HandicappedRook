# %% [markdown]
# # Shogi Notebook beta

# %%
from Engine import Engine # エンジン実行はまだ不安定です

program_dir = "H:\\shogi\\"
temp_dir = "Z:\\temp\\"

yaselmo = {
    "name": "yaselmo",
    "cwd":  program_dir + "yaselmo\\",
    "engine_cmd": program_dir + "yaselmo\\YaneuraOu-2017-early.exe Hash 1024 Threads 6",
    "stdout": temp_dir + "yaneuraou.txt",
    "option": [
        "setoption name USI_Ponder value False",
        "setoption name Threads value 6",
        "setoption name Hash value 1024",
        "setoption name NetworkDelay value 0",
        "setoption name NetworkDelay2 value 0",
        "setoption name EvalShare value false", 
        "setoption name BookMoves value 48",
        "setoption name EvalDir value eval"
    ]
}
nanoha = {
    "name": "nanoha",
    "cwd": program_dir + "NanohaTsumeUSI170417\\",
    "engine_cmd": program_dir + "NanohaTsumeUSI170417\\NanohaTsumeUSIx64.exe",
    "stdout": temp_dir + "nanoha.txt",
    "option": []
}
yomita = {
    "name": "yomita",
    "cwd": program_dir + "yomita_WCSC27\\",
    "engine_cmd": program_dir + "yomita_WCSC27\\yomita_avx2.exe",
    "stdout": temp_dir + "yomita.txt",
    "option": [
        "setoption name USI_Ponder value False",
        "setoption name Threads value 6",
        "setoption name EvalShare value False", 
        "setoption name EvalDir value eval\\kppt_file\\WCSC27",
        "setoption name ProgressDir value progress\\1"
    ]    
}
progress = {
    "name": "yomita_for_progress",
    "cwd": program_dir + "yomita_WCSC27\\",
    "engine_cmd": program_dir + "yomita_WCSC27\\yomita_avx2.exe",
    "stdout": temp_dir + "progress.txt",
    "option": [
        "setoption name USI_Ponder value False",
        "setoption name Threads value 1",
        "setoption name Hash value 16",
        "setoption name EvalShare value False", 
        "setoption name EvalDir value eval\\kppt_file\\WCSC27",
        "setoption name ProgressDir value progress\\1"
    ]
}

# %%
from Kifu import Kifu
from Kifu import battle

Yane = Engine(yaselmo, False)
Yane.init_engine()
Yane.usinewgame()

Yomita = Engine(yomita, False)
Yomita.init_engine()
Yomita.usinewgame()

Progress = Engine(progress, False)
Progress.init_engine()
Progress.usinewgame()

kifu_option_test = {
    "title": "対局テスト",
    "black_name": Yane.local_name,
    "white_name": Yomita.local_name,
    "teai": "平手",
    "comment": "コメント",
    "debug": "デバッグ情報"
}

kifu = Kifu(kifu_option=kifu_option_test)
battle(Yane, Yomita, kifu, Progress)

Yane.quit()
Yomita.quit()
Progress.quit()
# Out:
# ID:「yaselmo」
# USIコマンド： OK
# READY： OK
# ID:「Yomita_kppt_file4.0」
# USIコマンド： OK
# READY： OK
# ID:「Yomita_kppt_file4.0」
# USIコマンド： OK
# READY： OK
# bestmove: 2g2f 177
# bestmove: 3c3d
# bestmove: 2f2e 52
# bestmove: 2b3c
# bestmove: 7g7f 72
# bestmove: 3a2b
# bestmove: 3i4h 73
# bestmove: 8c8d
# bestmove: 8h3c+ 51
# bestmove: 2b3c
# bestmove: 7i8h 32
# bestmove: 7a6b
# bestmove: 8h7g 46
# bestmove: 7c7d -58
# bestmove: 3g3f 63
# bestmove: 4a3b -88
# bestmove: 4h3g 100
# bestmove: 8d8e -62
# bestmove: 6i7h 116
# bestmove: 6b7c -66
# bestmove: 5i6h 86
# bestmove: B*5d -15
# bestmove: 5g5f 157
# bestmove: 4c4d 24
# bestmove: 4i5h 151
# bestmove: 7c6d -38
# bestmove: 3g4f 190
# bestmove: 6a5b 14
# bestmove: 9g9f 124
# bestmove: 5a4a 116
# bestmove: 3f3e 151
# bestmove: 3d3e 75
# bestmove: 5f5e 98
# bestmove: 5d4c 91
# bestmove: 4f3e 33
# bestmove: P*3d 71
# bestmove: 2e2d 63
# bestmove: 2c2d 42
# bestmove: 3e2d 38
# bestmove: 3c2d 44
# bestmove: 2h2d 60
# bestmove: P*2c 52
# bestmove: 2d2h 36
# bestmove: 7d7e 58
# bestmove: 7f7e -31
# bestmove: 6d7e -40
# bestmove: P*7f 65
# bestmove: 8e8f 16
# bestmove: 8g8f 145
# bestmove: 7e7f -3
# bestmove: 7g7f 225
# bestmove: 4c7f -4
# bestmove: S*8g 123
# bestmove: 7f4c 40
# bestmove: P*7f 135
# bestmove: S*6d -1
# bestmove: 4g4f 214
# bestmove: P*7e -63
# bestmove: 4f4e 588
# bestmove: S*3c -74
# bestmove: 2i3g 525
# bestmove: P*8h -31
# bestmove: 7h8h 614
# bestmove: 4d4e -124
# bestmove: 3g4e 472
# bestmove: 3c4d -90
# bestmove: P*3c 552
# bestmove: 2a3c -33
# bestmove: 4e3c+ 677
# bestmove: 4d3c -212
# bestmove: N*2e 674
# bestmove: 3c4b -235
# bestmove: P*4d 626
# bestmove: 4c6e -157
# bestmove: 6g6f 615
# bestmove: 6e9b -122
# bestmove: 6h7i 775
# bestmove: P*4f -97
# bestmove: P*3c 603
# bestmove: 3b2b -152
# bestmove: 5e5d 514
# bestmove: 4f4g+ -68
# bestmove: 5h6h 402
# bestmove: 5c5d -98
# bestmove: S*6a 833
# bestmove: 5b5a -65
# bestmove: B*7a 475
# bestmove: 8b6b -231
# bestmove: 4d4c+ 145
# bestmove: 4b4c -18
# bestmove: P*4d 55
# bestmove: 4c4d 168
# bestmove: 6a7b 276
# bestmove: N*5f 172
# bestmove: 6h6g 402
# bestmove: 4g5g 310
# bestmove: 8h7h -240
# bestmove: 5g6g 570
# bestmove: 7h6g -178
# bestmove: 6b7b 557
# bestmove: 7a4d+ -258
# bestmove: G*5c 435
# bestmove: 4d3d -84
# bestmove: S*4c 465
# bestmove: 3d4e 62
# bestmove: P*4d 475
# bestmove: 4e3f 43
# bestmove: 2c2d 460
# bestmove: P*2c -21
# bestmove: 2b2c 517
# bestmove: P*5g -175
# bestmove: P*3e 515
# bestmove: 3f5h -145
# bestmove: 7e7f 534
# bestmove: 5g5f -223
# bestmove: 9b5f 613
# bestmove: 6g5f 27
# bestmove: 7f7g+ 560
# bestmove: B*8c -136
# bestmove: 7b7c 637
# bestmove: S*7d -21
# bestmove: 7c8c 707
# bestmove: 7d8c -150
# bestmove: 7g8g 661
# bestmove: R*2a -65
# bestmove: S*3a 660
# bestmove: 5h7f -168
# bestmove: P*8h 780
# bestmove: 2a2c+ -155
# bestmove: 8h8i+ 1166
# bestmove: 7i6h -197
# bestmove: B*3d 1076
# bestmove: 3c3b+ -335
# bestmove: 3a3b 1056
# bestmove: 2c2b -353
# bestmove: 3d5f 1170
# bestmove: 2e3c+ -44
# bestmove: 8g7h 1060
# bestmove: 6h5i -224
# bestmove: G*3a 1060
# bestmove: 3c3b -345
# bestmove: 4c3b 1140
# bestmove: 2b1a -828
# bestmove: 3b3c 1225
# bestmove: N*2c -475
# bestmove: 5f2c 1458
# bestmove: G*2a -531
# bestmove: 3a2a 1651
# bestmove: 1a2a -1008
# bestmove: N*3a 1780
# bestmove: L*3g -1312
# bestmove: G*2b 1835
# bestmove: 2a1a -1576
# bestmove: N*4e 1964
# bestmove: 3g3e -1638
# bestmove: P*3d 2096
# bestmove: P*2e -1703
# bestmove: 3d3e 2185
# bestmove: 2e2d -1694
# bestmove: L*5e 2338
# bestmove: P*5f -2007
# bestmove: 5e5f 2496
# bestmove: 5i4i -2176
# bestmove: 2c1d 2527
# bestmove: 2d2c+ -2300
# bestmove: 1d2c 2676
# bestmove: S*4f -2451
# bestmove: 3e3f 2753
# bestmove: G*4g -2671
# bestmove: 3f3g+ 2894
# bestmove: 4g3g -2904
# bestmove: 4e3g+ 3236
# bestmove: 4f3g -2952
# bestmove: G*4g 3251
# bestmove: 3g3f -3278
# bestmove: 4g3g 3260
# bestmove: 2h1h -3583
# bestmove: N*2f 4917
# bestmove: P*4b -4523
# bestmove: 5a4b 5630
# bestmove: 1h4h -5431
# bestmove: 5f5g+ mate 127
# bestmove: 1a3a mate -12
# bestmove: 4a3a mate 125
# bestmove: N*4c mate -10
# bestmove: 5c4c mate 123
# bestmove: 7f5h mate -12
# bestmove: R*2i mate 9
# bestmove: N*3i mate -8
# bestmove: 3g4h mate 7
# bestmove: 5h4h mate -6
# bestmove: R*6i mate 5
# bestmove: G*5i mate -4
# bestmove: 2c6g+ mate 3
# bestmove: 4h5h mate -2
# bestmove: 5g5h mate 1
# bestmove: resign mate -0

# %%
kifu.print_kifu_option()
kifu.stat()
kifu.nowBoard.plot()
print(f"棋譜：{kifu.get_sfen()}")
print(f"動かした駒の統計：{kifu.stat_move}")
# Out:
# ☗yaselmo VS ☖yomita
# 手合い： 平手
# 後手の勝ちです
# 勝った方の最小の評価値は-235
# 負けた方の最大の評価値は833
# 手数は196
# 先手玉の重心は(5.6896551724137927, 8.6551724137931032)
# 先手玉の最頻値は(6, 8)
# 後手玉の重心は(4.1448275862068966, 1.0)
# 後手玉の最頻値は(4, 1)
# 先手飛の重心は(2.0, 7.9100000000000001)
# 先手飛の最頻値は(2, 8)
# 後手飛の重心は(7.6494845360824746, 2.0309278350515463)
# 後手飛の最頻値は(8, 2)
# 先手の成りの回数は8
# 後手の成りの回数は7
# 棋譜：position sfen lnsgkgsnl/1r5b1/ppppppppp/9/9/9/PPPPPPPPP/1B5R1/LNSGKGSNL b - 1 moves 2g2f 3c3d 2f2e 2b3c 7g7f 3a2b 3i4h 8c8d 8h3c+ 2b3c 7i8h 7a6b 8h7g 7c7d 3g3f 4a3b 4h3g 8d8e 6i7h 6b7c 5i6h B*5d 5g5f 4c4d 4i5h 7c6d 3g4f 6a5b 9g9f 5a4a 3f3e 3d3e 5f5e 5d4c 4f3e P*3d 2e2d 2c2d 3e2d 3c2d 2h2d P*2c 2d2h 7d7e 7f7e 6d7e P*7f 8e8f 8g8f 7e7f 7g7f 4c7f S*8g 7f4c P*7f S*6d 4g4f P*7e 4f4e S*3c 2i3g P*8h 7h8h 4d4e 3g4e 3c4d P*3c 2a3c 4e3c+ 4d3c N*2e 3c4b P*4d 4c6e 6g6f 6e9b 6h7i P*4f P*3c 3b2b 5e5d 4f4g+ 5h6h 5c5d S*6a 5b5a B*7a 8b6b 4d4c+ 4b4c P*4d 4c4d 6a7b N*5f 6h6g 4g5g 8h7h 5g6g 7h6g 6b7b 7a4d+ G*5c 4d3d S*4c 3d4e P*4d 4e3f 2c2d P*2c 2b2c P*5g P*3e 3f5h 7e7f 5g5f 9b5f 6g5f 7f7g+ B*8c 7b7c S*7d 7c8c 7d8c 7g8g R*2a S*3a 5h7f P*8h 2a2c+ 8h8i+ 7i6h B*3d 3c3b+ 3a3b 2c2b 3d5f 2e3c+ 8g7h 6h5i G*3a 3c3b 4c3b 2b1a 3b3c N*2c 5f2c G*2a 3a2a 1a2a N*3a L*3g G*2b 2a1a N*4e 3g3e P*3d P*2e 3d3e 2e2d L*5e P*5f 5e5f 5i4i 2c1d 2d2c+ 1d2c S*4f 3e3f G*4g 3f3g+ 4g3g 4e3g+ 4f3g G*4g 3g3f 4g3g 2h1h N*2f P*4b 5a4b 1h4h 5f5g+ 1a3a 4a3a N*4c 5c4c 7f5h R*2i N*3i 3g4h 5h4h R*6i G*5i 2c6g+ 4h5h 5g5h
# 動かした駒の統計：OrderedDict([('K', 5), ('R', 5), ('B', 2), ('G', 9), ('S', 12), ('N', 4), ('L', 1), ('P', 20), ('+R', 5), ('+B', 8), ('+S', 0), ('+N', 1), ('+L', 0), ('+P', 0), ('*_b', 26), ('k', 2), ('r', 4), ('b', 12), ('g', 10), ('s', 16), ('n', 2), ('l', 2), ('p', 19), ('+r', 0), ('+b', 0), ('+s', 0), ('+n', 0), ('+l', 1), ('+p', 4), ('*_w', 26)])

# %%
# %matplotlib inline
kifu.plot_prog() # 進行度の推移をプロットします。

# %%
kifu.plot_score() # 評価値と駒割りの推移をプロットします。

# %%
kifu.plot_point() # 駒点数の推移をプロットします。

# %%
# 駒を移動させるサンプル
from Board import Board
from subject import subject
from Bitboard import B_BLACK, B_WHITE
A = Board(subject['横歩取り']['33角']['勇気'])
A.move("1a8h")
A.move("3d3c+")
A.move("2a3c")
A.plot()
A.count_b_bitboard(B_BLACK) # 先手陣の駒は15枚
A.get_x_pos2("+R")
# Out:
# [(3, 3)]

# %%
Yuuki = Board(subject['横歩取り']['33角']['勇気'])
print(Yuuki.get_sfen())
Yuuki.plot((6, 8))
# Out:
# sfen lnsgk1snl/6g2/p1ppppb1p/6R2/9/1rP6/P2PPPP1P/1BGK5/LNS2GSNL w 3P2p 18

# %%
Board(subject['ゴキゲン中飛車']['超急戦']['都成']).plot123((3, 3))
