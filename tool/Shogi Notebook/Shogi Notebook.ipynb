# %% [markdown]
# # Shogi Notebook beta

# %%
from Engine import Engine # エンジン実行はまだ不安定です

program_dir = "H:\\shogi\\"
temp_dir = "Z:\\temp\\"

yaselmo = {
    "name": "yaselmo",
    "cwd":  program_dir + "yaselmo\\",
    "engine_cmd": program_dir + "yaselmo\\YaneuraOu-2017-early.exe Hash 1024 Threads 6",
    "stdout": temp_dir + "yaneuraou.txt",
    "option": [
        "setoption name USI_Ponder value False",
        "setoption name Threads value 6",
        "setoption name Hash value 1024",
        "setoption name NetworkDelay value 0",
        "setoption name NetworkDelay2 value 0",
        "setoption name EvalShare value false", 
        "setoption name BookMoves value 48",
        "setoption name EvalDir value eval"
    ]
}
nanoha = {
    "name": "nanoha",
    "cwd": program_dir + "NanohaTsumeUSI170417\\",
    "engine_cmd": program_dir + "NanohaTsumeUSI170417\\NanohaTsumeUSIx64.exe",
    "stdout": temp_dir + "nanoha.txt",
    "option": []
}
yomita = {
    "name": "yomita",
    "cwd": program_dir + "yomita_WCSC27\\",
    "engine_cmd": program_dir + "yomita_WCSC27\\yomita_avx2.exe",
    "stdout": temp_dir + "yomita.txt",
    "option": [
        "setoption name USI_Ponder value False",
        "setoption name Threads value 6",
        "setoption name EvalShare value False", 
        "setoption name EvalDir value eval\\kppt_file\\WCSC27",
        "setoption name ProgressDir value progress\\1"
    ]    
}
progress = {
    "name": "yomita_for_progress",
    "cwd": program_dir + "yomita_WCSC27\\",
    "engine_cmd": program_dir + "yomita_WCSC27\\yomita_avx2.exe",
    "stdout": temp_dir + "progress.txt",
    "option": [
        "setoption name USI_Ponder value False",
        "setoption name Threads value 1",
        "setoption name Hash value 16",
        "setoption name EvalShare value False", 
        "setoption name EvalDir value eval\\kppt_file\\WCSC27",
        "setoption name ProgressDir value progress\\1"
    ]
}

# %%
from Kifu import Kifu
from Kifu import battle

Yane = Engine(yaselmo, False)
Yane.init_engine()
Yane.usinewgame()

Yomita = Engine(yomita, False)
Yomita.init_engine()
Yomita.usinewgame()

Progress = Engine(progress, False)
Progress.init_engine()
Progress.usinewgame()

kifu_option_test = {
    "title": "対局テスト",
    "black_name": Yane.local_name,
    "white_name": Yomita.local_name,
    "teai": "平手",
    "comment": "コメント",
    "debug": "デバッグ情報"
}

kifu = Kifu(kifu_option=kifu_option_test)
battle(Yane, Yomita, kifu, Progress)

Yane.quit()
Yomita.quit()
Progress.quit()
# Out:
# ID:「yaselmo」
# USIコマンド： OK
# READY： OK
# ID:「Yomita_kppt_file4.0」
# USIコマンド： OK
# READY： OK
# ID:「Yomita_kppt_file4.0」
# USIコマンド： OK
# READY： OK
# bestmove: 2g2f 126
# bestmove: 3c3d
# bestmove: 2f2e 72
# bestmove: 2b3c
# bestmove: 7g7f 68
# bestmove: 3a2b
# bestmove: 3i4h 48
# bestmove: 8c8d
# bestmove: 8h3c+ 51
# bestmove: 2b3c
# bestmove: 7i8h 47
# bestmove: 7a6b
# bestmove: 8h7g 84
# bestmove: 4a3b -46
# bestmove: 6i7h 44
# bestmove: 7c7d -90
# bestmove: 3g3f 76
# bestmove: 8d8e -47
# bestmove: 4h3g 92
# bestmove: 4c4d -66
# bestmove: 3g4f 262
# bestmove: 6a5b -96
# bestmove: 5i6h 227
# bestmove: 5b4c -92
# bestmove: 4i5h 257
# bestmove: 6b7c -141
# bestmove: 3f3e 283
# bestmove: 3d3e -82
# bestmove: 4f3e 292
# bestmove: B*5d -146
# bestmove: 5g5f 416
# bestmove: 7c6d -28
# bestmove: 3e4f 347
# bestmove: 4c4b -42
# bestmove: 2e2d 280
# bestmove: 2c2d -94
# bestmove: P*3d 270
# bestmove: 3c3d -47
# bestmove: 2h2d 307
# bestmove: 3b2c -42
# bestmove: 2d2f 295
# bestmove: P*2d -62
# bestmove: P*3e 198
# bestmove: 3d2e -97
# bestmove: 2f2h 311
# bestmove: 2e3f -122
# bestmove: B*1h 577
# bestmove: P*3g -246
# bestmove: 5f5e 604
# bestmove: 3g3h+ -302
# bestmove: 5e5d 685
# bestmove: 3h2h -431
# bestmove: 1h3f 1070
# bestmove: R*4i -362
# bestmove: 5d5c+ 1104
# bestmove: 6d5c -713
# bestmove: 3f6c+ 1122
# bestmove: 4i8i+ -562
# bestmove: 7h7i 1197
# bestmove: N*5f -564
# bestmove: 6h6i 1586
# bestmove: 8i9i -827
# bestmove: B*5e 1585
# bestmove: P*6d -947
# bestmove: 7g8h 2115
# bestmove: 9i9h -1236
# bestmove: S*8i 2266
# bestmove: 9h8i -1347
# bestmove: 7i8i 2315
# bestmove: 2h2i -1528
# bestmove: P*5d 2612
# bestmove: L*6h -1852
# bestmove: 6i7i 2996
# bestmove: 5c6b -2141
# bestmove: 6c6d 3115
# bestmove: S*7c -2128
# bestmove: 6d6e 3002
# bestmove: 8e8f -2130
# bestmove: 6e5f 2825
# bestmove: 8f8g+ -2142
# bestmove: 5f2c 2795
# bestmove: 5a6a -2105
# bestmove: 2c3d 3007
# bestmove: 6a7b -1971
# bestmove: N*6d 3305
# bestmove: 7b6c -2054
# bestmove: P*8c 3547
# bestmove: P*5g -2238
# bestmove: 5h6h 4113
# bestmove: 8b8c -2981
# bestmove: 3d6a 4365
# bestmove: 7c6d -2875
# bestmove: 5e6d 5857
# bestmove: 8g8h -3404
# bestmove: 8i8h 6141
# bestmove: 8c8h+ -3598
# bestmove: 7i8h 7511
# bestmove: P*8g -3733
# bestmove: 8h7h 8141
# bestmove: G*8h -4738
# bestmove: 7h7g 8758
# bestmove: N*8e -5132
# bestmove: 7g6f mate 15
# bestmove: P*6e -8247
# bestmove: 6f5f mate 11
# bestmove: S*4e mate -8
# bestmove: 4f4e mate 9
# bestmove: 4d4e mate -6
# bestmove: S*7b mate 5
# bestmove: 6c6d mate -4
# bestmove: G*5e mate 3
# bestmove: 6d7c mate -2
# bestmove: R*8c mate 1
# bestmove: resign mate 1

# %%
kifu.print_kifu_option()
kifu.stat()
kifu.nowBoard.plot()
print(f"棋譜：{kifu.get_sfen()}")
print(f"動かした駒の統計：{kifu.stat_move}")
# Out:
# ☗yaselmo VS ☖yomita
# 手合い： 平手
# 先手の勝ちです
# 勝った方の最小の評価値は0
# 負けた方の最大の評価値は0
# 手数は113
# 先手玉の重心は(5.9550561797752808, 8.4157303370786511)
# 先手玉の最頻値は(6, 8)
# 後手玉の重心は(5.2584269662921352, 1.4269662921348314)
# 後手玉の最頻値は(5, 1)
# 先手飛の重心は(2.0, 7.7446808510638299)
# 先手飛の最頻値は(2, 8)
# 後手飛の重心は(8.0, 2.1346153846153846)
# 後手飛の最頻値は(8, 2)
# 先手の成りの回数は3
# 後手の成りの回数は4
# 棋譜：position sfen lnsgkgsnl/1r5b1/ppppppppp/9/9/9/PPPPPPPPP/1B5R1/LNSGKGSNL b - 1 moves 2g2f 3c3d 2f2e 2b3c 7g7f 3a2b 3i4h 8c8d 8h3c+ 2b3c 7i8h 7a6b 8h7g 4a3b 6i7h 7c7d 3g3f 8d8e 4h3g 4c4d 3g4f 6a5b 5i6h 5b4c 4i5h 6b7c 3f3e 3d3e 4f3e B*5d 5g5f 7c6d 3e4f 4c4b 2e2d 2c2d P*3d 3c3d 2h2d 3b2c 2d2f P*2d P*3e 3d2e 2f2h 2e3f B*1h P*3g 5f5e 3g3h+ 5e5d 3h2h 1h3f R*4i 5d5c+ 6d5c 3f6c+ 4i8i+ 7h7i N*5f 6h6i 8i9i B*5e P*6d 7g8h 9i9h S*8i 9h8i 7i8i 2h2i P*5d L*6h 6i7i 5c6b 6c6d S*7c 6d6e 8e8f 6e5f 8f8g+ 5f2c 5a6a 2c3d 6a7b N*6d 7b6c P*8c P*5g 5h6h 8b8c 3d6a 7c6d 5e6d 8g8h 8i8h 8c8h+ 7i8h P*8g 8h7h G*8h 7h7g N*8e 7g6f P*6e 6f5f S*4e 4f4e 4d4e S*7b 6c6d G*5e 6d7c R*8c
# 動かした駒の統計：OrderedDict([('K', 8), ('R', 3), ('B', 4), ('G', 6), ('S', 9), ('N', 0), ('L', 0), ('P', 10), ('+R', 0), ('+B', 6), ('+S', 0), ('+N', 0), ('+L', 0), ('+P', 0), ('*_b', 11), ('k', 5), ('r', 3), ('b', 1), ('g', 5), ('s', 11), ('n', 0), ('l', 0), ('p', 11), ('+r', 3), ('+b', 0), ('+s', 0), ('+n', 0), ('+l', 0), ('+p', 3), ('*_w', 14)])

# %%
# %matplotlib inline
kifu.plot_prog() # 進行度の推移をプロットします。

# %%
kifu.plot_score() # 評価値と駒割りの推移をプロットします。

# %%
kifu.plot_point() # 駒点数の推移をプロットします。

# %%
# 駒を移動させるサンプル
from Board import Board
from subject import subject
from Bitboard import B_BLACK, B_WHITE
A = Board(subject['横歩取り']['33角']['勇気'])
A.move("1a8h")
A.move("3d3c+")
A.move("2a3c")
A.plot()
A.count_b_bitboard(B_BLACK) # 先手陣の駒は15枚
A.get_x_pos2("+R")
# Out:
# [(3, 3)]

# %%
Yuuki = Board(subject['横歩取り']['33角']['勇気'])
print(Yuuki.get_sfen())
Yuuki.plot((6, 8))
# Out:
# sfen lnsgk1snl/6g2/p1ppppb1p/6R2/9/1rP6/P2PPPP1P/1BGK5/LNS2GSNL w 3P2p 18

# %%
Board(subject['ゴキゲン中飛車']['超急戦']['都成']).plot123((3, 3))
