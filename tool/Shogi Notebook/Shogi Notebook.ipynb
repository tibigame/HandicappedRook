# %% [markdown]
# # Shogi Notebook beta

# %%
from Engine import Engine # エンジン実行はまだ不安定です

program_dir = "H:\\shogi\\"
temp_dir = "Z:\\temp\\"

yaselmo = {
    "name": "yaselmo",
    "cwd":  program_dir + "yaselmo\\",
    "engine_cmd": program_dir + "yaselmo\\YaneuraOu-2017-early.exe Hash 1024 Threads 6",
    "stdout": temp_dir + "yaneuraou.txt",
    "option": [
        "setoption name USI_Ponder value False",
        "setoption name Threads value 6",
        "setoption name Hash value 1024",
        "setoption name NetworkDelay value 0",
        "setoption name NetworkDelay2 value 0",
        "setoption name EvalShare value false", 
        "setoption name BookMoves value 48",
        "setoption name EvalDir value eval"
    ]
}
nanoha = {
    "name": "nanoha",
    "cwd": program_dir + "NanohaTsumeUSI170417\\",
    "engine_cmd": program_dir + "NanohaTsumeUSI170417\\NanohaTsumeUSIx64.exe",
    "stdout": temp_dir + "nanoha.txt",
    "option": []
}
yomita = {
    "name": "yomita",
    "cwd": program_dir + "yomita_WCSC27\\",
    "engine_cmd": program_dir + "yomita_WCSC27\\yomita_avx2.exe",
    "stdout": temp_dir + "yomita.txt",
    "option": [
        "setoption name USI_Ponder value False",
        "setoption name Threads value 6",
        "setoption name EvalShare value False", 
        "setoption name EvalDir value eval\\kppt_file\\WCSC27",
        "setoption name ProgressDir value progress\\1"
    ]    
}
progress = {
    "name": "yomita_for_progress",
    "cwd": program_dir + "yomita_WCSC27\\",
    "engine_cmd": program_dir + "yomita_WCSC27\\yomita_avx2.exe",
    "stdout": temp_dir + "progress.txt",
    "option": [
        "setoption name USI_Ponder value False",
        "setoption name Threads value 1",
        "setoption name Hash value 16",
        "setoption name EvalShare value False", 
        "setoption name EvalDir value eval\\kppt_file\\WCSC27",
        "setoption name ProgressDir value progress\\1"
    ]
}

# %%
from Board import Kifu
from Board import battle

Yane = Engine(yaselmo, False)
Yane.init_engine()
Yane.usinewgame()

Yomita = Engine(yomita, False)
Yomita.init_engine()
Yomita.usinewgame()

Progress = Engine(progress, False)
Progress.init_engine()
Progress.usinewgame()

kifu_option_test = {
    "title": "対局テスト",
    "black_name": Yane.local_name,
    "white_name": Yomita.local_name,
    "teai": "平手",
    "comment": "コメント",
    "debug": "デバッグ情報"
}

kifu = Kifu(kifu_option=kifu_option_test)
battle_test = battle(Yane, Yomita, kifu, Progress)

Yane.quit()
Yomita.quit()
Progress.quit()
# Out:
# ID:「yaselmo」
# USIコマンド： OK
# READY： OK
# ID:「Yomita_kppt_file4.0」
# USIコマンド： OK
# READY： OK
# ID:「Yomita_kppt_file4.0」
# USIコマンド： OK
# READY： OK
# bestmove: 2g2f 137
# bestmove: 3c3d
# bestmove: 7g7f 165
# bestmove: 8c8d
# bestmove: 2f2e 107
# bestmove: 8d8e
# bestmove: 9g9f 42
# bestmove: 8e8f 40
# bestmove: 8g8f 121
# bestmove: 4a3b 8
# bestmove: 8h2b+ 287
# bestmove: 3a2b -8
# bestmove: 2h8h 263
# bestmove: B*6e -24
# bestmove: 5i5h 252
# bestmove: 6e7f -48
# bestmove: 7i7h 274
# bestmove: 7f5d -45
# bestmove: 8i7g 348
# bestmove: 7c7d -1
# bestmove: 8f8e 294
# bestmove: 7d7e -38
# bestmove: 8e8d 661
# bestmove: P*8g -273
# bestmove: 7h8g 502
# bestmove: 6a7b -167
# bestmove: 8g7h 598
# bestmove: 7e7f -296
# bestmove: 7g8e 686
# bestmove: 8b8d -417
# bestmove: B*9e 852
# bestmove: P*8c -568
# bestmove: 8e9c 902
# bestmove: 9a9c -552
# bestmove: 9e8d 865
# bestmove: 8c8d -516
# bestmove: 8h8d 831
# bestmove: 8a7c -508
# bestmove: 8d8a+ 985
# bestmove: 5a4b -500
# bestmove: P*8d 784
# bestmove: 7c6e -440
# bestmove: 8d8c+ 1044
# bestmove: N*4e -484
# bestmove: 4i4h 912
# bestmove: 7f7g+ -445
# bestmove: 8c7b 1156
# bestmove: 7g7h -511
# bestmove: 6i7h 1203
# bestmove: 4e5g -538
# bestmove: 4h5g 1323
# bestmove: 6e5g+ -635
# bestmove: 5h5g 1341
# bestmove: S*6i -648
# bestmove: 7h7i 1852
# bestmove: G*5h -746
# bestmove: 5g5f 1951
# bestmove: B*5g -641
# bestmove: N*4f 2077
# bestmove: 5g7i+ -997
# bestmove: 4f5d 1920
# bestmove: 5c5d -1428
# bestmove: 5f6e 2831
# bestmove: G*6d -922
# bestmove: 6e7f 2326
# bestmove: 6d7d -1290
# bestmove: 7b7a 3001
# bestmove: P*7e -1354
# bestmove: 7f8f 1477
# bestmove: N*9d -1043
# bestmove: 8f8g 2102
# bestmove: 6i7h -981
# bestmove: 8g7g 884
# bestmove: 7i6h -1200
# bestmove: 7g8h 1181
# bestmove: 7d6e -1441
# bestmove: R*7b 1672
# bestmove: 4b3c -1322
# bestmove: B*7g 1945
# bestmove: 6e5e -1472
# bestmove: 7g6h 2871
# bestmove: 5h6h -1597
# bestmove: B*5a 2358
# bestmove: 3c4d -1910
# bestmove: N*3f 3295
# bestmove: 4d4e -2298
# bestmove: 7b7e+ 3735
# bestmove: B*7i -2422
# bestmove: 8h7g 3712
# bestmove: 6h6g -2653
# bestmove: 7g7f 4031
# bestmove: 7i5g+ -2804
# bestmove: S*4f 4643
# bestmove: 4e5f -3290
# bestmove: 4f5g 4962
# bestmove: 5f5g -3647
# bestmove: 7f8e 5098
# bestmove: P*8c -3723
# bestmove: 8e7d 6346
# bestmove: S*6f -4584
# bestmove: 7e8e 6665
# bestmove: 3d3e -4813
# bestmove: 7d8c 6726
# bestmove: 3e3f -5025
# bestmove: 5a8d+ 6853
# bestmove: N*2g -4777
# bestmove: 3i2h 6854
# bestmove: 2g1i+ -4804
# bestmove: 2h1i 6787
# bestmove: L*2g -4860
# bestmove: P*7c 6762
# bestmove: 2a3c -4784
# bestmove: 3g3f 6823
# bestmove: 2g2i+ -4826
# bestmove: 7c7b+ 6855
# bestmove: 2i1i -4845
# bestmove: 8c8b 6852
# bestmove: 3c2e -4938
# bestmove: 8d9c 6897
# bestmove: 5g4g -4906
# bestmove: P*8d 7247
# bestmove: 4g3h -5030
# bestmove: P*7d 7253
# bestmove: 2e1g+ -5103
# bestmove: 9f9e 7235
# bestmove: 9d8f -5087
# bestmove: 8d8c+ 7235
# bestmove: 6f7g -4975
# bestmove: 9e9d 7490
# bestmove: P*3g -4965
# bestmove: P*5f 7310
# bestmove: 5e5f -4711
# bestmove: G*3i 8192
# bestmove: 3h2g -5077
# bestmove: 8e2e 7794
# bestmove: N*2f -5422
# bestmove: B*3e 7837
# bestmove: 2g1h -5494
# bestmove: 2e2f 7695
# bestmove: S*1f -5412
# bestmove: 2f3g 7363
# bestmove: 1f2g+ -5190
# bestmove: 3g4h 7104
# bestmove: 1g2h -5236
# bestmove: 3e6b+ 7224
# bestmove: P*3h -5263
# bestmove: 3i2h 7171
# bestmove: 2g2h -5220
# bestmove: N*8e 7058
# bestmove: G*4g -4395
# bestmove: 7d7c+ 6220
# bestmove: 4g4h -4203
# bestmove: 9c4h 6008
# bestmove: R*8i -4316
# bestmove: 9i9e 5867
# bestmove: 6g5g -4278
# bestmove: 4h2f 5878
# bestmove: 1h2i -4284
# bestmove: 8e9c+ 5887
# bestmove: 2c2d -4257
# bestmove: 8b9a 6036
# bestmove: 8f9h+ -4000
# bestmove: 7c6c 5833
# bestmove: 8i8e+ -4021
# bestmove: 8c9b 5864
# bestmove: 8e9f -3934
# bestmove: L*5i 5843
# bestmove: P*6f -4006
# bestmove: 5i5g 6135
# bestmove: 5f5g -4028
# bestmove: 6b7c 6141
# bestmove: 6f6g+ -4045
# bestmove: 9c8c 6268
# bestmove: L*2e -4047
# bestmove: 2f6b 6720
# bestmove: 2e2g+ -3976
# bestmove: 9d9c+ 7827
# bestmove: 1c1d -4002
# bestmove: P*8b mate 3
# bestmove: 1d1e -3733
# bestmove: win mate 1

# %%
kifu.print_kifu_option()
kifu.stat()
kifu.nowBoard.plot()
print(f"棋譜：{kifu.get_sfen()}")
print(f"動かした駒の統計：{kifu.stat_move}")
# Out:
# ☗yaselmo VS ☖yomita
# 手合い： 平手
# 先手の勝ちです
# 勝った方の最小の評価値は42
# 負けた方の最大の評価値は40
# 手数は180
# 先手玉の重心は(6.8652482269503547, 5.1843971631205674)
# 先手玉の最頻値は(5, 8)
# 後手玉の重心は(3.7021276595744679, 4.6737588652482271)
# 後手玉の最頻値は(5, 1)
# 先手飛の重心は(5.833333333333333, 7.583333333333333)
# 先手飛の最頻値は(8, 8)
# 後手飛の重心は(8.0, 2.25)
# 後手飛の最頻値は(8, 2)
# 先手の成りの回数は11
# 後手の成りの回数は12
# 棋譜：position sfen lnsgkgsnl/1r5b1/ppppppppp/9/9/9/PPPPPPPPP/1B5R1/LNSGKGSNL b - 1 moves 2g2f 3c3d 7g7f 8c8d 2f2e 8d8e 9g9f 8e8f 8g8f 4a3b 8h2b+ 3a2b 2h8h B*6e 5i5h 6e7f 7i7h 7f5d 8i7g 7c7d 8f8e 7d7e 8e8d P*8g 7h8g 6a7b 8g7h 7e7f 7g8e 8b8d B*9e P*8c 8e9c 9a9c 9e8d 8c8d 8h8d 8a7c 8d8a+ 5a4b P*8d 7c6e 8d8c+ N*4e 4i4h 7f7g+ 8c7b 7g7h 6i7h 4e5g 4h5g 6e5g+ 5h5g S*6i 7h7i G*5h 5g5f B*5g N*4f 5g7i+ 4f5d 5c5d 5f6e G*6d 6e7f 6d7d 7b7a P*7e 7f8f N*9d 8f8g 6i7h 8g7g 7i6h 7g8h 7d6e R*7b 4b3c B*7g 6e5e 7g6h 5h6h B*5a 3c4d N*3f 4d4e 7b7e+ B*7i 8h7g 6h6g 7g7f 7i5g+ S*4f 4e5f 4f5g 5f5g 7f8e P*8c 8e7d S*6f 7e8e 3d3e 7d8c 3e3f 5a8d+ N*2g 3i2h 2g1i+ 2h1i L*2g P*7c 2a3c 3g3f 2g2i+ 7c7b+ 2i1i 8c8b 3c2e 8d9c 5g4g P*8d 4g3h P*7d 2e1g+ 9f9e 9d8f 8d8c+ 6f7g 9e9d P*3g P*5f 5e5f G*3i 3h2g 8e2e N*2f B*3e 2g1h 2e2f S*1f 2f3g 1f2g+ 3g4h 1g2h 3e6b+ P*3h 3i2h 2g2h N*8e G*4g 7d7c+ 4g4h 9c4h R*8i 9i9e 6g5g 4h2f 1h2i 8e9c+ 2c2d 8b9a 8f9h+ 7c6c 8i8e+ 8c9b 8e9f L*5i P*6f 5i5g 5f5g 6b7c 6f6g+ 9c8c L*2e 2f6b 2e2g+ 9d9c+ 1c1d P*8b 1d1e
# 動かした駒の統計：OrderedDict([('K', 16), ('R', 4), ('B', 5), ('G', 5), ('S', 6), ('N', 5), ('L', 2), ('P', 15), ('+R', 5), ('+B', 5), ('+S', 0), ('+N', 1), ('+L', 0), ('+P', 4), ('*_b', 17), ('k', 11), ('r', 2), ('b', 4), ('g', 11), ('s', 4), ('n', 10), ('l', 3), ('p', 16), ('+r', 1), ('+b', 1), ('+s', 1), ('+n', 1), ('+l', 1), ('+p', 1), ('*_w', 23)])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.plot(kifu.stat_progress) # 進行度のグラフを出してみる

# %%
# 駒を移動させるサンプル
from Board import Board
from subject import subject
from Bitboard import B_BLACK, B_WHITE
A = Board(subject['横歩取り']['33角']['勇気'])
A.move("1a8h")
A.move("3d3c+")
A.move("2a3c")
A.plot()
A.count_b_bitboard(B_BLACK) # 先手陣の駒は15枚
# Out:
# 15

# %%
Yuuki = Board(subject['横歩取り']['33角']['勇気'])
print(Yuuki.get_sfen())
Yuuki.plot((6, 8))
# Out:
# sfen lnsgk1snl/6g2/p1ppppb1p/6R2/9/1rP6/P2PPPP1P/1BGK5/LNS2GSNL w 3P2p 18

# %%
Board(subject['ゴキゲン中飛車']['超急戦']['都成']).plot123((3, 3))
