# %% [markdown]
# # Shogi Notebook beta

# %%
from Engine import Engine # エンジン実行はまだ不安定です

program_dir = "H:\\shogi\\"
temp_dir = "Z:\\temp\\"

yaselmo = {
    "name": "yaselmo",
    "cwd":  program_dir + "yaselmo\\",
    "engine_cmd": program_dir + "yaselmo\\YaneuraOu-2017-early.exe Hash 1024 Threads 6",
    "stdout": temp_dir + "yaneuraou.txt",
    "option": [
        "setoption name USI_Ponder value False",
        "setoption name Threads value 6",
        "setoption name Hash value 1024",
        "setoption name NetworkDelay value 0",
        "setoption name NetworkDelay2 value 0",
        "setoption name EvalShare value false", 
        "setoption name BookMoves value 48",
        "setoption name EvalDir value eval"
    ]
}
nanoha = {
    "name": "nanoha",
    "cwd": program_dir + "NanohaTsumeUSI170417\\",
    "engine_cmd": program_dir + "NanohaTsumeUSI170417\\NanohaTsumeUSIx64.exe",
    "stdout": temp_dir + "nanoha.txt",
    "option": []
}
yomita = {
    "name": "yomita",
    "cwd": program_dir + "yomita_WCSC27\\",
    "engine_cmd": program_dir + "yomita_WCSC27\\yomita_avx2.exe",
    "stdout": temp_dir + "yomita.txt",
    "option": [
        "setoption name USI_Ponder value False",
        "setoption name Threads value 6",
        "setoption name EvalShare value False", 
        "setoption name EvalDir value eval\\kppt_file\\WCSC27",
        "setoption name ProgressDir value progress\\1"
    ]    
}
progress = {
    "name": "yomita_for_progress",
    "cwd": program_dir + "yomita_WCSC27\\",
    "engine_cmd": program_dir + "yomita_WCSC27\\yomita_avx2.exe",
    "stdout": temp_dir + "progress.txt",
    "option": [
        "setoption name USI_Ponder value False",
        "setoption name Threads value 1",
        "setoption name Hash value 16",
        "setoption name EvalShare value False", 
        "setoption name EvalDir value eval\\kppt_file\\WCSC27",
        "setoption name ProgressDir value progress\\1"
    ]
}

# %%
from Kifu import Kifu
from Kifu import battle

Yane = Engine(yaselmo, False)
Yane.init_engine()
Yane.usinewgame()

Yomita = Engine(yomita, False)
Yomita.init_engine()
Yomita.usinewgame()

Progress = Engine(progress, False)
Progress.init_engine()
Progress.usinewgame()

kifu_option_test = {
    "title": "対局テスト",
    "black_name": Yane.local_name,
    "white_name": Yomita.local_name,
    "teai": "平手",
    "comment": "コメント",
    "debug": "デバッグ情報"
}

kifu = Kifu(kifu_option=kifu_option_test)
battle(Yane, Yomita, kifu, Progress)

Yane.quit()
Yomita.quit()
Progress.quit()
# Out:
# ID:「yaselmo」
# USIコマンド： OK
# READY： OK
# ID:「Yomita_kppt_file4.0」
# USIコマンド： OK
# READY： OK
# ID:「Yomita_kppt_file4.0」
# USIコマンド： OK
# READY： OK
# bestmove: 7g7f 118
# bestmove: 3c3d
# bestmove: 2g2f 76
# bestmove: 8c8d
# bestmove: 2f2e 104
# bestmove: 8d8e
# bestmove: 6i7h 96
# bestmove: 4a3b
# bestmove: 5i5h 91
# bestmove: 8e8f 150
# bestmove: 8g8f 100
# bestmove: 8b8f 146
# bestmove: 2e2d 138
# bestmove: 2c2d 162
# bestmove: 2h2d 110
# bestmove: 5a4a
# bestmove: 8h2b+ 470
# bestmove: 3a2b
# bestmove: B*7g 880
# bestmove: 8f8b
# bestmove: P*8c 1371
# bestmove: 8b5b
# bestmove: 3i3h 191
# bestmove: 5c5d -11
# bestmove: 3g3f 186
# bestmove: P*2c -141
# bestmove: 2d2e 161
# bestmove: 7c7d -41
# bestmove: 2i3g 114
# bestmove: B*6d -152
# bestmove: 2e6e 181
# bestmove: 6a6b -120
# bestmove: 3f3e 68
# bestmove: 8a7c 80
# bestmove: 6e6d -73
# bestmove: 6c6d 138
# bestmove: 7g6f -97
# bestmove: 3d3e 178
# bestmove: 3g4e -86
# bestmove: 5d5e 265
# bestmove: 7i6h -332
# bestmove: 4c4d 440
# bestmove: 7f7e -463
# bestmove: 4d4e 460
# bestmove: 7e7d -412
# bestmove: 7c6e 460
# bestmove: 7d7c+ -420
# bestmove: 6b7c 570
# bestmove: B*2e -557
# bestmove: N*4c 661
# bestmove: 8i7g -587
# bestmove: 7c6c 766
# bestmove: P*7d -677
# bestmove: R*7f 1083
# bestmove: 7h7i -920
# bestmove: 7f7d 1254
# bestmove: 2e3d -867
# bestmove: P*7f 1558
# bestmove: 3d4e -1238
# bestmove: 6c5c 1593
# bestmove: P*7e -1731
# bestmove: 7d8d 1706
# bestmove: 4e8a+ -1808
# bestmove: 7f7g+ 1718
# bestmove: 6h7g -1787
# bestmove: 7a6b 1656
# bestmove: 7g6h -1922
# bestmove: N*5d 1807
# bestmove: 8c8b+ -1938
# bestmove: P*7f 1828
# bestmove: 8b7b -2044
# bestmove: 6b5a 1914
# bestmove: 8a9a -2114
# bestmove: 5d6f 1967
# bestmove: 5h4h -2144
# bestmove: 5e5f 2185
# bestmove: 7b6a -2211
# bestmove: 5f5g+ 2144
# bestmove: 4h3g -2314
# bestmove: B*5e 2327
# bestmove: L*4f -2313
# bestmove: 5a4b 2442
# bestmove: 9a7c -2340
# bestmove: 8d8g+ 2401
# bestmove: P*5d -2118
# bestmove: P*4e 2203
# bestmove: 7c7d -1970
# bestmove: 5g4g 2095
# bestmove: 3g2g -1767
# bestmove: 4g3h 1924
# bestmove: 4i3h -2371
# bestmove: S*6c 2306
# bestmove: 5d5c+ -1193
# bestmove: 5b5c 1494
# bestmove: P*5d -1390
# bestmove: 6c7d 1662
# bestmove: 5d5c+ -1304
# bestmove: 4b5c 1641
# bestmove: R*5a -754
# bestmove: 4a4b 1548
# bestmove: P*3d -1004
# bestmove: B*6c 1014
# bestmove: 5a2a+ -1388
# bestmove: 4e4f 934
# bestmove: 2g1f -1550
# bestmove: 2b3a 855
# bestmove: 7e7d -1583
# bestmove: 1c1d 903
# bestmove: S*5a -1408
# bestmove: 4b5b 865
# bestmove: G*6b -875
# bestmove: 5c6b 956
# bestmove: 6a6b -1446
# bestmove: 5b5c 1091
# bestmove: 6b6c -1984
# bestmove: 5c6c 1264
# bestmove: B*4a -1953
# bestmove: 6c5d 1230
# bestmove: 7d7c+ -2185
# bestmove: 1d1e 1600
# bestmove: 1f2g -1270
# bestmove: L*2d 1348
# bestmove: N*2f -1243
# bestmove: 5d4e 1094
# bestmove: S*5d -996
# bestmove: 4e5d 1767
# bestmove: 4a6c+ -2131
# bestmove: 5d4d 2244
# bestmove: 2a3b -2502
# bestmove: S*3f 2262
# bestmove: 6c3f -2144
# bestmove: 3e3f 2554
# bestmove: 3b4c -3086
# bestmove: 4d4c 2856
# bestmove: 3d3c+ -3337
# bestmove: 4c3c 3042
# bestmove: S*3d -1925
# bestmove: 3c2b 3377
# bestmove: 2g3f -2601
# bestmove: P*3e mate 21
# bestmove: 3f3e mate -12
# bestmove: G*4d mate 19
# bestmove: 3e3f mate -10
# bestmove: R*3e mate 15
# bestmove: 3f2g mate -8
# bestmove: B*3f mate 13
# bestmove: 2g2h mate -10
# bestmove: 4f4g+ mate 11
# bestmove: N*3g mate -8
# bestmove: 2d2f mate 9
# bestmove: G*2g mate -6
# bestmove: 2f2g+ mate 5
# bestmove: 3h2g mate -4
# bestmove: G*3h mate 3
# bestmove: 2h1h mate -2
# bestmove: N*2f mate 1
# bestmove: resign mate -0

# %%
kifu.print_kifu_option()
kifu.stat()
kifu.nowBoard.plot()
print(f"棋譜：{kifu.get_sfen()}")
print(f"動かした駒の統計：{kifu.stat_move}")
# Out:
# ☗yaselmo VS ☖yomita
# 手合い： 平手
# 後手の勝ちです
# 勝った方の最小の評価値は-152
# 負けた方の最大の評価値は1371
# 手数は156
# 先手玉の重心は(3.6000000000000001, 7.541666666666667)
# 先手玉の最頻値は(5, 8)
# 後手玉の重心は(4.0499999999999998, 1.5833333333333333)
# 後手玉の最頻値は(4, 1)
# 先手飛の重心は(2.7272727272727271, 6.0303030303030303)
# 先手飛の最頻値は(2, 8)
# 後手飛の重心は(6.76056338028169, 3.084507042253521)
# 後手飛の最頻値は(5, 2)
# 先手の成りの回数は10
# 後手の成りの回数は5
# 棋譜：position sfen lnsgkgsnl/1r5b1/ppppppppp/9/9/9/PPPPPPPPP/1B5R1/LNSGKGSNL b - 1 moves 7g7f 3c3d 2g2f 8c8d 2f2e 8d8e 6i7h 4a3b 5i5h 8e8f 8g8f 8b8f 2e2d 2c2d 2h2d 5a4a 8h2b+ 3a2b B*7g 8f8b P*8c 8b5b 3i3h 5c5d 3g3f P*2c 2d2e 7c7d 2i3g B*6d 2e6e 6a6b 3f3e 8a7c 6e6d 6c6d 7g6f 3d3e 3g4e 5d5e 7i6h 4c4d 7f7e 4d4e 7e7d 7c6e 7d7c+ 6b7c B*2e N*4c 8i7g 7c6c P*7d R*7f 7h7i 7f7d 2e3d P*7f 3d4e 6c5c P*7e 7d8d 4e8a+ 7f7g+ 6h7g 7a6b 7g6h N*5d 8c8b+ P*7f 8b7b 6b5a 8a9a 5d6f 5h4h 5e5f 7b6a 5f5g+ 4h3g B*5e L*4f 5a4b 9a7c 8d8g+ P*5d P*4e 7c7d 5g4g 3g2g 4g3h 4i3h S*6c 5d5c+ 5b5c P*5d 6c7d 5d5c+ 4b5c R*5a 4a4b P*3d B*6c 5a2a+ 4e4f 2g1f 2b3a 7e7d 1c1d S*5a 4b5b G*6b 5c6b 6a6b 5b5c 6b6c 5c6c B*4a 6c5d 7d7c+ 1d1e 1f2g L*2d N*2f 5d4e S*5d 4e5d 4a6c+ 5d4d 2a3b S*3f 6c3f 3e3f 3b4c 4d4c 3d3c+ 4c3c S*3d 3c2b 2g3f P*3e 3f3e G*4d 3e3f R*3e 3f2g B*3f 2g2h 4f4g+ N*3g 2d2f G*2g 2f2g+ 3h2g G*3h 2h1h N*2f
# 動かした駒の統計：OrderedDict([('K', 12), ('R', 5), ('B', 6), ('G', 4), ('S', 4), ('N', 3), ('L', 0), ('P', 16), ('+R', 2), ('+B', 4), ('+S', 0), ('+N', 0), ('+L', 0), ('+P', 4), ('*_b', 18), ('k', 12), ('r', 7), ('b', 0), ('g', 5), ('s', 8), ('n', 3), ('l', 2), ('p', 20), ('+r', 0), ('+b', 0), ('+s', 0), ('+n', 0), ('+l', 0), ('+p', 2), ('*_w', 19)])

# %%
# %matplotlib inline
kifu.plot_prog() # 進行度の推移をプロットします。

# %%
kifu.plot_score() # 評価値と駒割りの推移をプロットします。

# %%
# 駒を移動させるサンプル
from Board import Board
from subject import subject
from Bitboard import B_BLACK, B_WHITE
A = Board(subject['横歩取り']['33角']['勇気'])
A.move("1a8h")
A.move("3d3c+")
A.move("2a3c")
A.plot()
A.count_b_bitboard(B_BLACK) # 先手陣の駒は15枚
A.get_x_pos2("+R")
# Out:
# [(3, 3)]

# %%
Yuuki = Board(subject['横歩取り']['33角']['勇気'])
print(Yuuki.get_sfen())
Yuuki.plot((6, 8))
# Out:
# sfen lnsgk1snl/6g2/p1ppppb1p/6R2/9/1rP6/P2PPPP1P/1BGK5/LNS2GSNL w 3P2p 18

# %%
Board(subject['ゴキゲン中飛車']['超急戦']['都成']).plot123((3, 3))
