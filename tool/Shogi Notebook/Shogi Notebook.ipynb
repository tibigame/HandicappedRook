# %% [markdown]
# # Shogi Notebook beta

# %%
from Engine import Engine # エンジン実行はまだ不安定です

program_dir = "H:\\shogi\\"
temp_dir = "Z:\\temp\\"

yaselmo = {
    "name": "yaselmo",
    "cwd":  program_dir + "yaselmo\\",
    "engine_cmd": program_dir + "yaselmo\\YaneuraOu-2017-early.exe Hash 1024 Threads 6",
    "stdout": temp_dir + "yaneuraou.txt",
    "option": [
        "setoption name USI_Ponder value False",
        "setoption name Threads value 6",
        "setoption name Hash value 1024",
        "setoption name NetworkDelay value 0",
        "setoption name NetworkDelay2 value 0",
        "setoption name EvalShare value false", 
        "setoption name BookMoves value 48",
        "setoption name EvalDir value eval"
    ]
}
nanoha = {
    "name": "nanoha",
    "cwd": program_dir + "NanohaTsumeUSI170417\\",
    "engine_cmd": program_dir + "NanohaTsumeUSI170417\\NanohaTsumeUSIx64.exe",
    "stdout": temp_dir + "nanoha.txt",
    "option": []
}
yomita = {
    "name": "yomita",
    "cwd": program_dir + "yomita_WCSC27\\",
    "engine_cmd": program_dir + "yomita_WCSC27\\yomita_avx2.exe",
    "stdout": temp_dir + "yomita.txt",
    "option": [
        "setoption name USI_Ponder value False",
        "setoption name Threads value 6",
        "setoption name EvalShare value False", 
        "setoption name EvalDir value eval\\kppt_file\\WCSC27",
        "setoption name ProgressDir value progress\\1"
    ]    
}
progress = {
    "name": "yomita_for_progress",
    "cwd": program_dir + "yomita_WCSC27\\",
    "engine_cmd": program_dir + "yomita_WCSC27\\yomita_avx2.exe",
    "stdout": temp_dir + "progress.txt",
    "option": [
        "setoption name USI_Ponder value False",
        "setoption name Threads value 1",
        "setoption name Hash value 16",
        "setoption name EvalShare value False", 
        "setoption name EvalDir value eval\\kppt_file\\WCSC27",
        "setoption name ProgressDir value progress\\1"
    ]
}

# %%
from Kifu import Kifu
from Kifu import battle

Yane = Engine(yaselmo, False)
Yane.init_engine()
Yane.usinewgame()

Yomita = Engine(yomita, False)
Yomita.init_engine()
Yomita.usinewgame()

Progress = Engine(progress, False)
Progress.init_engine()
Progress.usinewgame()

kifu_option_test = {
    "title": "対局テスト",
    "black_name": Yane.local_name,
    "white_name": Yomita.local_name,
    "teai": "平手",
    "comment": "コメント",
    "debug": "デバッグ情報"
}

kifu = Kifu(kifu_option=kifu_option_test)
battle(Yane, Yomita, kifu, Progress)

Yane.quit()
Yomita.quit()
Progress.quit()
# Out:
# ID:「yaselmo」
# USIコマンド： OK
# READY： OK
# ID:「Yomita_kppt_file4.0」
# USIコマンド： OK
# READY： OK
# ID:「Yomita_kppt_file4.0」
# USIコマンド： OK
# READY： OK
# bestmove: 2g2f 103
# bestmove: 3c3d
# bestmove: 7g7f 83
# bestmove: 8c8d
# bestmove: 2f2e 40
# bestmove: 8d8e
# bestmove: 5i5h 112
# bestmove: 8e8f
# bestmove: 8g8f 201
# bestmove: 8b8f
# bestmove: 8h2b+ 335
# bestmove: 3a2b
# bestmove: B*7g 357
# bestmove: 8f8b
# bestmove: 2e2d 207
# bestmove: 2c2d
# bestmove: P*8c 198
# bestmove: 8b5b
# bestmove: 2h2d 147
# bestmove: 4a3b
# bestmove: 7i7h 90
# bestmove: 5c5d -115
# bestmove: 3i4h 177
# bestmove: B*3c 1
# bestmove: 7g3c+ 106
# bestmove: 2a3c 40
# bestmove: B*7g 48
# bestmove: 5d5e 67
# bestmove: 4i3i 81
# bestmove: 2b2c 12
# bestmove: 2d2h 33
# bestmove: P*2d 142
# bestmove: 3g3f 41
# bestmove: 5e5f 146
# bestmove: 5g5f 51
# bestmove: 5b5f 125
# bestmove: 5h4i 48
# bestmove: 5f3f 192
# bestmove: 7g6f 147
# bestmove: 3f5f 180
# bestmove: 4h5g 244
# bestmove: 5f5b 83
# bestmove: 5g4f 170
# bestmove: B*4d 18
# bestmove: P*5e 304
# bestmove: 5a4a 66
# bestmove: 2h5h 316
# bestmove: 6a5a 34
# bestmove: 3i3h 425
# bestmove: 5a4b -33
# bestmove: 5e5d 506
# bestmove: 4d6f -75
# bestmove: 6g6f 608
# bestmove: P*5f -68
# bestmove: 5h5f 718
# bestmove: P*8g -160
# bestmove: B*5c 936
# bestmove: B*4d -214
# bestmove: 5c4d+ 1055
# bestmove: 4c4d -437
# bestmove: B*5c 1194
# bestmove: B*6b -460
# bestmove: 8c8b+ 1268
# bestmove: 8g8h+ -648
# bestmove: 7h6g 1336
# bestmove: 6b5c -630
# bestmove: 5d5c+ 1440
# bestmove: 5b8b -740
# bestmove: P*8c 1857
# bestmove: 8b8c -814
# bestmove: 5c4b 2063
# bestmove: 3b4b -1148
# bestmove: P*5c 2274
# bestmove: P*5a -854
# bestmove: B*2b 2493
# bestmove: 4a3b -1208
# bestmove: 2b1a+ 2588
# bestmove: B*2b -1520
# bestmove: 1a2b 2858
# bestmove: 3b2b -1803
# bestmove: 5c5b+ 3010
# bestmove: 5a5b -1973
# bestmove: L*4c 3194
# bestmove: 4b4c -1857
# bestmove: 5f5b+ 3241
# bestmove: B*3b -1918
# bestmove: B*6e 3301
# bestmove: 8c8b -1996
# bestmove: 6e4c+ 3344
# bestmove: 8b5b -2106
# bestmove: 4c5b 3327
# bestmove: R*8g -2207
# bestmove: G*6h 3447
# bestmove: L*3f -2081
# bestmove: P*3g 3905
# bestmove: 4d4e -2506
# bestmove: R*5a 5216
# bestmove: 8h9i -3037
# bestmove: 5b4b 7812
# bestmove: L*4a mate -12
# bestmove: 5a7a+ mate 11
# bestmove: 1c1d mate -10
# bestmove: S*3a mate 9
# bestmove: 2b1c mate -8
# bestmove: 4b3c mate 7
# bestmove: 1d1e mate -6
# bestmove: N*2f mate 5
# bestmove: 2d2e mate -4
# bestmove: 3a2b mate 3
# bestmove: 1c1b mate -2
# bestmove: G*1c mate 1
# bestmove: resign mate 1

# %%
kifu.print_kifu_option()
kifu.stat()
kifu.nowBoard.plot()
print(f"棋譜：{kifu.get_sfen()}")
print(f"動かした駒の統計：{kifu.stat_move}")
# Out:
# ☗yaselmo VS ☖yomita
# 手合い： 平手
# 先手の勝ちです
# 勝った方の最小の評価値は0
# 負けた方の最大の評価値は192
# 手数は111
# 先手玉の重心は(4.3902439024390247, 8.6951219512195124)
# 先手玉の最頻値は(4, 9)
# 後手玉の重心は(3.8780487804878048, 1.3414634146341464)
# 後手玉の最頻値は(5, 1)
# 先手飛の重心は(3.2089552238805972, 6.7462686567164178)
# 先手飛の最頻値は(2, 8)
# 後手飛の重心は(6.211267605633803, 2.6619718309859155)
# 後手飛の最頻値は(5, 2)
# 先手の成りの回数は10
# 後手の成りの回数は1
# 棋譜：position sfen lnsgkgsnl/1r5b1/ppppppppp/9/9/9/PPPPPPPPP/1B5R1/LNSGKGSNL b - 1 moves 2g2f 3c3d 7g7f 8c8d 2f2e 8d8e 5i5h 8e8f 8g8f 8b8f 8h2b+ 3a2b B*7g 8f8b 2e2d 2c2d P*8c 8b5b 2h2d 4a3b 7i7h 5c5d 3i4h B*3c 7g3c+ 2a3c B*7g 5d5e 4i3i 2b2c 2d2h P*2d 3g3f 5e5f 5g5f 5b5f 5h4i 5f3f 7g6f 3f5f 4h5g 5f5b 5g4f B*4d P*5e 5a4a 2h5h 6a5a 3i3h 5a4b 5e5d 4d6f 6g6f P*5f 5h5f P*8g B*5c B*4d 5c4d+ 4c4d B*5c B*6b 8c8b+ 8g8h+ 7h6g 6b5c 5d5c+ 5b8b P*8c 8b8c 5c4b 3b4b P*5c P*5a B*2b 4a3b 2b1a+ B*2b 1a2b 3b2b 5c5b+ 5a5b L*4c 4b4c 5f5b+ B*3b B*6e 8c8b 6e4c+ 8b5b 4c5b R*8g G*6h L*3f P*3g 4d4e R*5a 8h9i 5b4b L*4a 5a7a+ 1c1d S*3a 2b1c 4b3c 1d1e N*2f 2d2e 3a2b 1c1b G*1c
# 動かした駒の統計：OrderedDict([('K', 2), ('R', 6), ('B', 6), ('G', 2), ('S', 6), ('N', 0), ('L', 0), ('P', 12), ('+R', 0), ('+B', 4), ('+S', 0), ('+N', 0), ('+L', 0), ('+P', 1), ('*_b', 17), ('k', 5), ('r', 11), ('b', 2), ('g', 5), ('s', 2), ('n', 1), ('l', 0), ('p', 15), ('+r', 0), ('+b', 0), ('+s', 0), ('+n', 0), ('+l', 0), ('+p', 1), ('*_w', 13)])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.plot(kifu.stat_progress) # 進行度のグラフを出してみる

# %%
# 駒を移動させるサンプル
from Board import Board
from subject import subject
from Bitboard import B_BLACK, B_WHITE
A = Board(subject['横歩取り']['33角']['勇気'])
A.move("1a8h")
A.move("3d3c+")
A.move("2a3c")
A.plot()
A.count_b_bitboard(B_BLACK) # 先手陣の駒は15枚
# Out:
# 15

# %%
Yuuki = Board(subject['横歩取り']['33角']['勇気'])
print(Yuuki.get_sfen())
Yuuki.plot((6, 8))
# Out:
# sfen lnsgk1snl/6g2/p1ppppb1p/6R2/9/1rP6/P2PPPP1P/1BGK5/LNS2GSNL w 3P2p 18

# %%
Board(subject['ゴキゲン中飛車']['超急戦']['都成']).plot123((3, 3))
